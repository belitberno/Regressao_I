# %% [markdown]
# # Regressão 01 - tarefa 01

# %% [markdown]
# ### 1. Explorando a base de gorjetas
#
# a. Na aula fizemos uma regressão de ```tip``` explicada por ```net_bill```. Carregue os pacotes e a base, crie as variáveis necessárias como na aula, e reproduza esta regressão.
#
# b. Reproduza também o gráfico de dispersão dessas duas variáveis.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import load_dataset

import statsmodels.formula.api as smf

from sklearn.metrics import r2_score

# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips['net_bill'] = tips['total_bill'] - tips['tip']
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct  net_bill
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.063204     15.98
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.191244      8.68
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.199886     17.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.162494     20.37
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.172069     20.98

# %%
reg_tip = smf.ols(formula='tip ~ net_bill', 
                  data=tips
                 ).fit()

reg_tip.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tip   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.330
# Method:                 Least Squares   F-statistic:                     120.6
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):           5.02e-23
# Time:                        19:01:49   Log-Likelihood:                -375.63
# No. Observations:                 244   AIC:                             755.3
# Df Residuals:                     242   BIC:                             762.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3307      0.168      7.907      0.000       0.999       1.662
# net_bill       0.0993      0.009     10.980      0.000       0.082       0.117
# ==============================================================================
# Omnibus:                       33.873   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.942
# Skew:                           0.754   Prob(JB):                     9.63e-14
# Kurtosis:                       4.903   Cond. No.                         43.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Gráfico de dispersão
sns.regplot(y = 'tip', x = 'net_bill', data = tips[tips['tip_pct']<.5])

# Gerando dados para a linha dos 10%
x = np.linspace(0,tips['net_bill'].max(),100)
y = .1*x

# Plotando a linha dos 10%
plt.plot(x, y, '-r', label='linha dos 10%')

# Opções estéticas para explicitar o (0,0) no gráfico
plt.xlim(left = 0)
plt.ylim(bottom = 0)
# Out:
# (0.0, 10.5)

# %% [markdown]
# ### 2. Mudança de perspectiva
#
# Agora ajuste um modelo de regressão de ```tip_pct``` por ```net_bill```. Construa o gráfico de dispersão correspondente.

# %%
reg_tip_pct = smf.ols('tip_pct ~ net_bill', data = tips).fit()
reg_tip_pct.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                tip_pct   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     24.31
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):           1.52e-06
# Time:                        18:59:11   Log-Likelihood:                 108.00
# No. Observations:                 244   AIC:                            -212.0
# Df Residuals:                     242   BIC:                            -205.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3053      0.023     13.166      0.000       0.260       0.351
# net_bill      -0.0061      0.001     -4.931      0.000      -0.009      -0.004
# ==============================================================================
# Omnibus:                      468.674   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           234437.604
# Skew:                          11.104   Prob(JB):                         0.00
# Kurtosis:                     153.221   Cond. No.                         43.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
tips['tip_pct_predict'] = reg_tip_pct.predict(tips)

# %%
plt.figure(figsize=(14,7))

sns.regplot(x='net_bill', y='tip_pct', data=tips, label='tip_pct')
plt.plot(tips['net_bill'], tips['tip_pct_predict'], 'r+', label='tip_pct_predict')

plt.legend()
plt.xlim(left=0)
plt.ylim(bottom=0)

plt.xticks(ticks=np.arange(stop=tips['net_bill'].max(), step=1))
plt.yticks(ticks=np.arange(stop=tips['tip_pct'].max(), step=.50))

plt.show()

# %% [markdown]
# ### 3. Comente
#
# Compare os dois gráficos e comente (de forma objetiva e suscinta) a relação entre eles e a diferença do ajuste. Podemos comparar diretamente os $R^2$s?

# %% [markdown]
# - É possivel observar em ambos os gráficos a concentração de menores valores liquidos da conta, os dados diminuem conforme o valor de conta aumenta. A primeira análise do gráfico de dispersão difere da segunda, a medida que os valores de net bill aumentam, os valores da tip aumentam também, os dados do segundo gráfico apresentam uma correlação inversa entre o net bill e tip pct, quando o net bill aumenta, a tip pct diminui. Em ambos os modelos é possivel verificar um baixo coeficiente de determinação (R2), porém o primeiro modelo tem um melhor ajuste aos dados.

# %% [markdown]
# ### 4. Ajuste do modelo em outra escala
#
# Com o modelo no item 3, obtenha a preditiva do valor da gorjeta:

# %% [markdown]
# 1. obtenha o valor predito ```pred``` para ```tip_pct``` (dica, veja o atributo ```reg.fittedvalues```)

# %%
reg_tip_pct.fittedvalues
# Out:
# 0      0.207087
# 1      0.251951
# 2      0.197684
# 3      0.180107
# 4      0.176358
#          ...
# 239    0.163268
# 240    0.150546
# 241    0.178264
# 242    0.206534
# 243    0.208316
# Length: 244, dtype: float64

# %% [markdown]
# 2. obtenha o valor predito para ```tip``` como ```tip_pct * net_bill```

# %%
reg_tip_pct.fittedvalues * tips.net_bill
# Out:
# 0      3.309254
# 1      2.186938
# 2      3.461450
# 3      3.668785
# 4      3.699998
#          ...
# 239    3.773120
# 240    3.790751
# 241    3.684707
# 242    3.319003
# 243    3.287232
# Length: 244, dtype: float64

# %% [markdown]
#   3. calcule o $R^2$ do modelo para ```tip```

# %%
r2 = r2_score(y_true=tips['tip'], 
              y_pred=reg_tip_pct.fittedvalues * tips.net_bill)

print("Coeficiente de determinação (𝑅2) do modelo para tip:", r2)
# Out:
# Coeficiente de determinação (𝑅2) do modelo para tip: 0.1088997484546137

# %% [markdown]
#  4. compare esse $R^2$ com o do item 1

# %%
print('Coeficiente de determinação (𝑅2) dos valores preditos para `tip` como tip_pct(predict) * net_bill:', 
      round(r2 * 100, 2), '%')

print('Coeficiente de determinação (𝑅2) do modelo `reg_tip`:', 
      round(reg_tip.rsquared * 100, 2), '%')

print('Coeficiente de determinação (𝑅2) do modelo `reg_tip_pct`:', 
      round(reg_tip_pct.rsquared * 100, 2), '%')
# Out:
# Coeficiente de determinação (𝑅2) dos valores preditos para `tip` como tip_pct(predict) * net_bill: 10.89 %
# Coeficiente de determinação (𝑅2) do modelo `reg_tip`: 33.25 %
# Coeficiente de determinação (𝑅2) do modelo `reg_tip_pct`: 9.13 %
